# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 파일이 있는 폴더로 이동

# %%
cd /content/drive/MyDrive/vgg
# Out:
# /content/drive/MyDrive/vgg

# %% [markdown]
# # Argument 선언하여 main.py 실행

# %%
# !python main.py --mode train --lr 1e-4 --batch_size 16 --num_epochs 10
# Out:
# {'architecture': 'VGG16',
#  'batch_size': 16,
#  'data_dir': './datasets',
#  'lr': 0.0001,
#  'mode': 'train',
#  'num_epochs': 10}
# Epoch 1/10
# ----------
# 100% 75/75 [00:31<00:00,  2.41it/s]
# Train Loss: 0.8851	Accuracy: 0.5267
# 100% 10/10 [00:01<00:00,  6.54it/s]
# Valid Loss: 1.2330	Accuracy: 0.5067
# Epoch 2/10
# ----------
# 100% 75/75 [00:30<00:00,  2.43it/s]
# Train Loss: 0.8080	Accuracy: 0.5450
# 100% 10/10 [00:01<00:00,  5.79it/s]
# Valid Loss: 1.3683	Accuracy: 0.6467
# Epoch 3/10
# ----------
# 100% 75/75 [00:30<00:00,  2.50it/s]
# Train Loss: 0.8175	Accuracy: 0.6108
# 100% 10/10 [00:01<00:00,  6.61it/s]
# Valid Loss: 0.6998	Accuracy: 0.6333
# Epoch 4/10
# ----------
# 100% 75/75 [00:29<00:00,  2.51it/s]
# Train Loss: 0.6753	Accuracy: 0.6083
# 100% 10/10 [00:01<00:00,  5.68it/s]
# Valid Loss: 0.6646	Accuracy: 0.7200
# Epoch 5/10
# ----------
# 100% 75/75 [00:30<00:00,  2.50it/s]
# Train Loss: 0.6445	Accuracy: 0.6542
# 100% 10/10 [00:01<00:00,  6.71it/s]
# ...

# %%
# !python main.py --mode test
# Out:
# 100% 5/5 [00:02<00:00,  1.71it/s]
# Test Loss: 0.5910	Accuracy: 0.7333
